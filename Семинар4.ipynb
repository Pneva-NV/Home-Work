# %% [markdown]
# <a href="https://colab.research.google.com/github/Pneva-NV/Home-Work/blob/main/%D0%A1%D0%B5%D0%BC%D0%B8%D0%BD%D0%B0%D1%804.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_data='/content/drive/MyDrive/laptops_10.csv'

# %%
df=pd.read_csv(file_data, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# 1            128  FlashStorage
# 2            256           SSD
# 3            512           SSD
# 4            256           SSD

# %% [markdown]
# ## Задача 1
# *   Постройте график.
# *   Назовите график.
# *   Сделайте именование оси х и оси у.
# *   Сделайте выводы.
# ### Задание 1.1
# Изучите количество памяти с помощью matplotlib.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_m_type=df['Memory_Type'].value_counts()

# %%
names = data_m_type.index
values = data_m_type.values
names, values
# Out:
# (Index(['SSD', 'HDD', 'FlashStorage', 'Hybrid'], dtype='object'),
#  array([641, 576,  74,  12]))

# %%
plt.pie(values, labels=names, autopct='%.1f%%');

# %% [markdown]
# ### Задание 1.2
# Изучите стоимость ноутбуков с помощью matplotlib.

# %%
plt.boxplot(df['Price_euros']);

# %% [markdown]
# ### Задание 1.3
# Изучите вес ноутбуков с помощью matplotlib.

# %%
data_weight = df['Weight'].value_counts()

# %%
names = data_weight.index
values = data_weight.values

# %%
plt.bar(x=names, height=values)
plt.xlabel('Вес')
plt.ylabel('Количество')
plt.title('Вес ноутбуков');

# %%
plt.hist(df['Weight'])
plt.xlabel('Вес')
plt.ylabel('Количество')
plt.title('Вес ноутбуков');

# %% [markdown]
# ## Задача 2
# *   Постройте график.
# *   Сделайте выводы.
# ### Задание 2.1
# Изучите распределение типов носителя.

# %%
plt.hist(df['Memory_Amount'])
plt.xlabel('ГБ')
plt.ylabel('Количество')
plt.title('Распределение типов носителя');

# %% [markdown]
# Выводы: больше всего 256 типов носителей.

# %% [markdown]
# ### Задание 2.2
# Изучите распределение компаний производителей.

# %%
data_comp = df['Company'].value_counts()

# %%
names = data_comp.index
values = data_comp.values

# %%
plt.figure(figsize=(9, 6))
plt.bar(x=names, height=values)
plt.xticks(rotation=50)
plt.title('Распределение компаний производителей');

# %% [markdown]
# Больше всего ноутбуков выпускает компания Dell.

# %% [markdown]
# ### Задание 2.3
# Изучите распределение операционной системы.

# %%
data_ops = df['OpSys'].value_counts()

# %%
names = data_ops.index
values = data_ops.values

# %%
plt.figure(figsize=(6, 4))
plt.bar(x=names, height=values)
plt.xticks(rotation=30)
plt.title('Распределение операционной системы');

# %% [markdown]
# Больше всего ОС Windows10.

# %% [markdown]
# ### Задание 2.4
# Изучите распределение компаний производителей CPU.

# %%
data_cpu_c=df['Cpu_Company'].value_counts()

# %%
names = data_cpu_c.index
values = data_cpu_c.values

# %%
plt.pie(values, labels=names, autopct='%.1f%%');

# %% [markdown]
# Большую долю ранка по CPU захватила коаминия Intel.

# %% [markdown]
# ### Задача 3
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму. Процессоры от Samsung не изучайте.
# ## Задание 3.1
# Постройте график в абсолютных величинах.

# %%
data_table = pd.crosstab(df['Company'], df['Cpu_Company'])

# %%
data_table
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
data_table = data_table.drop(columns = ['Samsung']).reset_index()

# %%
data_table
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
names = data_table.index
values = data_table.values

# %%
plt.figure(figsize=(8, 5))
n_ticks = np.arange(len(data_table['Company']))
offset = 0.2
w = 0.4
plt.bar(n_ticks - offset, data_table['AMD'], width=w)
plt.bar(n_ticks + offset, data_table['Intel'], width=w)

plt.xlabel('Company name')
plt.ylabel('Cpu company')
plt.xticks(n_ticks, data_table['Company'], rotation=50)
plt.title('Histogram companies bar')
plt.legend(['AMD', 'Intel']);

# %% [markdown]
# ### Задание 3.2
# Постройте график в относительных величинах.

# %%
data_table = pd.crosstab(df['Company'], df['Cpu_Company'], normalize='index')

# %%
data_table = data_table.drop(columns = ['Samsung']).reset_index()

# %%
names = data_table.index
values = data_table.values

# %%
plt.figure(figsize=(10, 5))
plt.bar(data_table['Company'], data_table['AMD'])
plt.bar(data_table['Company'], data_table['Intel'], bottom=data_table['AMD'])

plt.xlabel('Company name')
plt.ylabel('Cpu company')
plt.xticks(rotation=50)
plt.title('Histogram companies bar');
plt.legend(['AMD', 'Intel']);

# %% [markdown]
# ## Задача 4
# *   постройте график;
# *   назовите график;
# *   сделайте именование оси х и у;
# *   сделайте выводы.
# ### Задание 4.1
# Изучите взаимосвязь стоимости ноутбука и компании производителя процессора.

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(x=df['Price_euros'], y=df['Cpu_Company'], whis=1.5)

plt.xlabel('Price_euros')
plt.ylabel('Cpu Company')
plt.title('Price nout - cpu company');

# %% [markdown]
# ### Задание 4.2
# Изучите взаимосвязь стоимости ноутбука и типа носителя памяти.

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(x=df['Price_euros'], y=df['Memory_Type'], whis=1.5)

plt.xlabel('Price_euros')
plt.ylabel('Memory_Type')
plt.title('Price nout - Memory_Type');

# %% [markdown]
# ### Задание 4.3
# Изучите взаимосвязь стоимости ноутбука и количества оперативной памяти.

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(x=df['Price_euros'], y=df['Ram'], whis=1.5)

plt.xlabel('Price_euros')
plt.ylabel('Ram')
plt.title('Price nout - Ram');

# %% [markdown]
# ### Задание 4.4
# Изучите взаимосвязь стоимости ноутбука и компании производителя.

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(x=df['Price_euros'], y=df['Company'], whis=1.5)

plt.xlabel('Price_euros')
plt.ylabel('Company')
plt.title('Price nout - Company');

# %% [markdown]
# ## Задача 5
# Постройте матрицу коррекляций для таблицы.

# %%
corr_matrix = df.corr(numeric_only = True)
corr_matrix = np.round(corr_matrix, 1)
corr_matrix[np.abs(corr_matrix) < 0.3] = 0
corr_matrix
# Out:
#                Inches  Weight  Price_euros  Memory_Amount
# Inches            1.0     0.8          0.0            0.3
# Weight            0.8     1.0          0.0            0.0
# Price_euros       0.0     0.0          1.0            0.0
# Memory_Amount     0.3     0.0          0.0            1.0

# %%
sns.heatmap(corr_matrix, annot=True, linewidths = 0.5, cmap='coolwarm');
